# %%
# Importing python packages 
import numpy as np  # numpy!
import seaborn as sns # visualisation!
import matplotlib.pyplot as plt # visualisation!
import pandas as pd # dataframes & data analysis!

# %%
# Importing the data 
dataset = 'Life Expectancy Data.csv'
df = pd.read_csv(dataset)

# %%
pd.reset_option('display.max_columns')
df.head()
# Out:
#    Country          Region  Year  Infant_deaths  Under_five_deaths  \
# 0  Turkiye     Middle East  2015           11.1               13.0
# 1    Spain  European Union  2015            2.7                3.3
# 2    India            Asia  2007           51.5               67.9
# 3   Guyana   South America  2006           32.8               40.5
# 4   Israel     Middle East  2012            3.4                4.3
#
#    Adult_mortality  Alcohol_consumption  Hepatitis_B  Measles   BMI  ...  \
# 0         105.8240                 1.32           97       65  27.8  ...
# 1          57.9025                10.35           97       94  26.0  ...
# 2         201.0765                 1.57           60       35  21.2  ...
# 3         222.1965                 5.68           93       74  25.3  ...
# 4          57.9510                 2.89           97       89  27.0  ...
#
#    Diphtheria  Incidents_HIV  GDP_per_capita  Population_mln  \
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Year', 'Infant_deaths', 'Under_five_deaths',
#        'Adult_mortality', 'Alcohol_consumption', 'Hepatitis_B', 'Measles',
#        'BMI', 'Polio', 'Diphtheria', 'Incidents_HIV', 'GDP_per_capita',
#        'Population_mln', 'Thinness_ten_nineteen_years',
#        'Thinness_five_nine_years', 'Schooling', 'Economy_status_Developed',
#        'Economy_status_Developing', 'Life_expectancy'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Country                         object
# Region                          object
# Year                             int64
# Infant_deaths                  float64
# Under_five_deaths              float64
# Adult_mortality                float64
# Alcohol_consumption            float64
# Hepatitis_B                      int64
# Measles                          int64
# BMI                            float64
# Polio                            int64
# Diphtheria                       int64
# Incidents_HIV                  float64
# GDP_per_capita                   int64
# Population_mln                 float64
# Thinness_ten_nineteen_years    float64
# Thinness_five_nine_years       float64
# Schooling                      float64
# Economy_status_Developed         int64
# Economy_status_Developing        int64
# Life_expectancy                float64
# dtype: object

# %%
df.loc[((df['Hepatitis_B'] >=100) | 
        (df['Polio'] >=100) | 
       (df['Diphtheria'] >=100) | 
       (df['Thinness_ten_nineteen_years'] >=100) |
       (df['Thinness_five_nine_years'] >=100)), : ]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Year, Infant_deaths, Under_five_deaths, Adult_mortality, Alcohol_consumption, Hepatitis_B, Measles, BMI, Polio, Diphtheria, Incidents_HIV, GDP_per_capita, Population_mln, Thinness_ten_nineteen_years, Thinness_five_nine_years, Schooling, Economy_status_Developed, Economy_status_Developing, Life_expectancy]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.loc[((df['Infant_deaths'] >=100) | 
        (df['Under_five_deaths'] >=100) | 
       (df['Adult_mortality'] >=100) | 
       (df['Alcohol_consumption'] >=100) |
       (df['Life_expectancy'] >=100)), : ]
# Out:
#                  Country          Region  Year  Infant_deaths  \
# 0                Turkiye     Middle East  2015           11.1
# 2                  India            Asia  2007           51.5
# 3                 Guyana   South America  2006           32.8
# 6     Russian Federation  Rest of Europe  2015            6.6
# 7                Hungary  European Union  2000            8.7
# ...                  ...             ...   ...            ...
# 2858  Iran, Islamic Rep.     Middle East  2007           19.7
# 2859               Niger          Africa  2000           97.0
# 2860            Mongolia            Asia  2009           23.9
# 2861           Sri Lanka            Asia  2004           17.7
# 2862           Lithuania  European Union  2002            7.9
#
#       Under_five_deaths  Adult_mortality  Alcohol_consumption  Hepatitis_B  \
# 0                  13.0         105.8240                1.320           97
# ...

# %% [markdown]
# |Columns | In Notebook | In Metadata | Standardisation |
# |------- |------- |------- |------- |
# |Country| yes | yes ||
# |Region| yes | **no** ||
# |Year| yes | yes ||
# |Adult_mortality| yes | yes | yes |
# |Infant_deaths| yes | yes | yes |
# |Economy_status_Developed| yes | **'Status'** ||
# |Economy_status_Developed| yes | **'Status'** ||
# |Infant_deaths| yes | yes ||
# |Alcohol_consumption| yes | **'Alcohol'** ||
# |percentage expenditure| **no** | yes ||
# |Hepatitis_B| yes | yes ||
# |Measles| yes | yes | yes |
# |BMI| yes | yes ||
# |Under_five_deaths| yes | yes | yes |
# |Polio| yes | yes ||
# |Total expenditure| **no** | yes ||
# |Diphtheria| yes | yes ||
# |Incidents_HIV| yes | **'HIV/AIDS'** | yes |
# |GDP_per_capita| yes | **'GDP'** ||
# |Population_mln| yes | yes ||
# |Thinness_ten_nineteen_years| yes | **'thinness 1-19 years'** ||
# |Thinness_five_nine_years| yes | yes ||
# |Income composition of resources| **no** | yes ||
# |Schooling| yes | yes | yes |
